# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import ERFutils

# %% [markdown]
# # Load data and diagnose patterns
# This notebook uses a standard pattern scaling methodology (i.e. regressing local temperatures against the global mean temperature) to generate the temperature change pattern for a given experiment.

# %%
# Specify if we want to plot and/or save resultant Green's function
plot = True
save_data = False
save_fig = False

# Using 1pctCO2 experiment for training
train = '1pctCO2'

# Diagnose Green's function
G_ds = ERFutils.diagnose_mean_pattern(train, plot, save_data, save_fig)
