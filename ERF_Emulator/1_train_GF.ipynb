# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import ERFutils

# %% [markdown]
# # Load data and diagnose Green's functions
# This notebook diagnoses the multimodel mean Green's function; the multimodel mean Green's function is chosen as a way to reduce the impact of internal variability, which can lead to unstable Green's functions.
#
# More details can be found in ERFutils.diagnose_mean_GF().

# %%
# Specify if we want to plot and/or save resultant Green's function
plot = True
save_data = False
save_fig = False

# Using 1pctCO2 experiment for training
train = '1pctCO2'

# Diagnose Green's function
G_ds = ERFutils.diagnose_mean_GF(train, plot, save_data, save_fig)
