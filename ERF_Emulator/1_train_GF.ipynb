# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import ERFutils

# %% [markdown]
# # Load data and diagnose Green's functions
# This notebook diagnoses either the multimodel mean Green's function or the Green's function for each individual model. Uncomment the final lines in this notebook to diagnose response functions for training datasets other than <i>1pctCO2</i>.
#
# More details can be found in ERFutils.diagnose_GF().

# %%
# Specify if we want to find the multimodel mean, plot, and/or save resultant Green's function
plot = True
save_data = False
save_fig = False

# Using 1pctCO2 experiment for training
train = '1pctCO2'

# Diagnose Green's function
G_mean_ds = ERFutils.diagnose_GF(train, True, plot, save_data, save_fig)

#for train in ['ssp126','ssp245','ssp370','ssp585']:
#    G_mean_ds = ERFutils.diagnose_GF(train, True, plot, save_data, save_fig)
#    G_multi_ds = ERFutils.diagnose_GF(train, False, plot, save_data, save_fig)
